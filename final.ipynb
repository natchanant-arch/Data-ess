# %% [markdown]
# <a href="https://colab.research.google.com/github/natchanant-arch/Data-ess/blob/main/final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## ส่วนที่ 0 — Import

# %%
import random
import time
from datetime import datetime, timedelta
# !pip install Faker
from faker import Faker
fake = Faker("th_TH")
random.seed(1)
import pandas as pd
import matplotlib, os, shutil
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import seaborn as sns
# Out:
# Collecting Faker
#   Downloading faker-40.37.0-py3-none-any.whl.metadata (16 kB)
# Downloading faker-40.37.0-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 22.7 MB/s eta 0:00:00
# Installing collected packages: Faker
# Successfully installed Faker-40.37.0

# %%
# 1. ติดตั้งฟอนต์ภาษาไทย
# !apt-get -y install fonts-thai-tlwg

# 2. ล้าง cache ของ matplotlib เพื่ออัปเดตฟอนต์ใหม่
cache_dir = matplotlib.get_cachedir()
if os.path.exists(cache_dir):
    shutil.rmtree(cache_dir)

# 3. ลงทะเบียนฟอนต์ใหม่เข้ากับ FontManager
font_path = '/usr/share/fonts/truetype/tlwg/Loma.ttf'
if os.path.exists(font_path):
    fm.fontManager.addfont(font_path)

# 4. ตั้งค่าฟอนต์หลัก
plt.rcParams['font.family'] = 'Loma'
plt.rcParams['axes.unicode_minus'] = False

# 5. สร้างข้อมูลจำลองและแสดงผล
data = {
    'เมือง': ['กรุงเทพฯ', 'เชียงใหม่', 'ภูเก็ต'],
    'อุณหภูมิ': [30.5, 25.2, 28.9]
}
df_thai = pd.DataFrame(data)

print("ตั้งค่าระบบฟอนต์ภาษาไทยสำเร็จ!")
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   fonts-tlwg-garuda fonts-tlwg-garuda-ttf fonts-tlwg-kinnari
#   fonts-tlwg-kinnari-ttf fonts-tlwg-laksaman fonts-tlwg-laksaman-ttf
#   fonts-tlwg-loma fonts-tlwg-loma-ttf fonts-tlwg-mono fonts-tlwg-mono-ttf
#   fonts-tlwg-norasi fonts-tlwg-norasi-ttf fonts-tlwg-purisa
#   fonts-tlwg-purisa-ttf fonts-tlwg-sawasdee fonts-tlwg-sawasdee-ttf
#   fonts-tlwg-typewriter fonts-tlwg-typewriter-ttf fonts-tlwg-typist
#   fonts-tlwg-typist-ttf fonts-tlwg-typo fonts-tlwg-typo-ttf fonts-tlwg-umpush
#   fonts-tlwg-umpush-ttf fonts-tlwg-waree fonts-tlwg-waree-ttf
# The following NEW packages will be installed:
#   fonts-thai-tlwg fonts-tlwg-garuda fonts-tlwg-garuda-ttf fonts-tlwg-kinnari
#   fonts-tlwg-kinnari-ttf fonts-tlwg-laksaman fonts-tlwg-laksaman-ttf
#   fonts-tlwg-loma fonts-tlwg-loma-ttf fonts-tlwg-mono fonts-tlwg-mono-ttf
#   fonts-tlwg-norasi fonts-tlwg-norasi-ttf fonts-tlwg-purisa
#   fonts-tlwg-purisa-ttf fonts-tlwg-sawasdee fonts-tlwg-sawasdee-ttf
#   fonts-tlwg-typewriter fonts-tlwg-typewriter-ttf fonts-tlwg-typist
#   fonts-tlwg-typist-ttf fonts-tlwg-typo fonts-tlwg-typo-ttf fonts-tlwg-umpush
#   fonts-tlwg-umpush-ttf fonts-tlwg-waree fonts-tlwg-waree-ttf
# 0 upgraded, 27 newly installed, 0 to remove and 4 not upgraded.
# Need to get 2,805 kB of archives.
# After this operation, 6,974 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-tlwg-garuda-ttf all 1:0.7.3-1 [152 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-tlwg-garuda all 1:0.7.3-1 [4,360 B]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-tlwg-kinnari-ttf all 1:0.7.3-1 [290 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-tlwg-kinnari all 1:0.7.3-1 [4,362 B]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-tlwg-laksaman-ttf all 1:0.7.3-1 [192 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-tlwg-laksaman all 1:0.7.3-1 [4,346 B]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-tlwg-loma-ttf all 1:0.7.3-1 [170 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-tlwg-loma all 1:0.7.3-1 [4,102 B]
# Get:9 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-tlwg-mono-ttf all 1:0.7.3-1 [175 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-tlwg-mono all 1:0.7.3-1 [4,072 B]
# Get:11 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-tlwg-norasi-ttf all 1:0.7.3-1 [331 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-tlwg-norasi all 1:0.7.3-1 [4,082 B]
# Get:13 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-tlwg-purisa-ttf all 1:0.7.3-1 [313 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-tlwg-purisa all 1:0.7.3-1 [3,556 B]
# Get:15 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-tlwg-sawasdee-ttf all 1:0.7.3-1 [171 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-tlwg-sawasdee all 1:0.7.3-1 [3,574 B]
# Get:17 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-tlwg-typewriter-ttf all 1:0.7.3-1 [178 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-tlwg-typewriter all 1:0.7.3-1 [3,630 B]
# Get:19 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-tlwg-typist-ttf all 1:0.7.3-1 [177 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-tlwg-typist all 1:0.7.3-1 [4,066 B]
# Get:21 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-tlwg-typo-ttf all 1:0.7.3-1 [177 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-tlwg-typo all 1:0.7.3-1 [4,106 B]
# Get:23 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-tlwg-umpush-ttf all 1:0.7.3-1 [236 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-tlwg-umpush all 1:0.7.3-1 [4,340 B]
# Get:25 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-tlwg-waree-ttf all 1:0.7.3-1 [178 kB]
# Get:26 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-tlwg-waree all 1:0.7.3-1 [4,092 B]
# Get:27 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-thai-tlwg all 1:0.7.3-1 [9,356 B]
# Fetched 2,805 kB in 0s (6,025 kB/s)
# Selecting previously unselected package fonts-tlwg-garuda-ttf.
# (Reading database ... 118422 files and directories currently installed.)
# Preparing to unpack .../00-fonts-tlwg-garuda-ttf_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-garuda-ttf (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-garuda.
# Preparing to unpack .../01-fonts-tlwg-garuda_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-garuda (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-kinnari-ttf.
# Preparing to unpack .../02-fonts-tlwg-kinnari-ttf_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-kinnari-ttf (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-kinnari.
# Preparing to unpack .../03-fonts-tlwg-kinnari_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-kinnari (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-laksaman-ttf.
# Preparing to unpack .../04-fonts-tlwg-laksaman-ttf_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-laksaman-ttf (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-laksaman.
# Preparing to unpack .../05-fonts-tlwg-laksaman_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-laksaman (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-loma-ttf.
# Preparing to unpack .../06-fonts-tlwg-loma-ttf_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-loma-ttf (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-loma.
# Preparing to unpack .../07-fonts-tlwg-loma_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-loma (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-mono-ttf.
# Preparing to unpack .../08-fonts-tlwg-mono-ttf_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-mono-ttf (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-mono.
# Preparing to unpack .../09-fonts-tlwg-mono_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-mono (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-norasi-ttf.
# Preparing to unpack .../10-fonts-tlwg-norasi-ttf_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-norasi-ttf (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-norasi.
# Preparing to unpack .../11-fonts-tlwg-norasi_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-norasi (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-purisa-ttf.
# Preparing to unpack .../12-fonts-tlwg-purisa-ttf_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-purisa-ttf (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-purisa.
# Preparing to unpack .../13-fonts-tlwg-purisa_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-purisa (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-sawasdee-ttf.
# Preparing to unpack .../14-fonts-tlwg-sawasdee-ttf_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-sawasdee-ttf (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-sawasdee.
# Preparing to unpack .../15-fonts-tlwg-sawasdee_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-sawasdee (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-typewriter-ttf.
# Preparing to unpack .../16-fonts-tlwg-typewriter-ttf_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-typewriter-ttf (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-typewriter.
# Preparing to unpack .../17-fonts-tlwg-typewriter_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-typewriter (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-typist-ttf.
# Preparing to unpack .../18-fonts-tlwg-typist-ttf_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-typist-ttf (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-typist.
# Preparing to unpack .../19-fonts-tlwg-typist_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-typist (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-typo-ttf.
# Preparing to unpack .../20-fonts-tlwg-typo-ttf_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-typo-ttf (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-typo.
# Preparing to unpack .../21-fonts-tlwg-typo_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-typo (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-umpush-ttf.
# Preparing to unpack .../22-fonts-tlwg-umpush-ttf_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-umpush-ttf (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-umpush.
# Preparing to unpack .../23-fonts-tlwg-umpush_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-umpush (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-waree-ttf.
# Preparing to unpack .../24-fonts-tlwg-waree-ttf_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-waree-ttf (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-waree.
# Preparing to unpack .../25-fonts-tlwg-waree_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-waree (1:0.7.3-1) ...
# Selecting previously unselected package fonts-thai-tlwg.
# Preparing to unpack .../26-fonts-thai-tlwg_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-thai-tlwg (1:0.7.3-1) ...
# Setting up fonts-tlwg-garuda-ttf (1:0.7.3-1) ...
# Setting up fonts-tlwg-laksaman-ttf (1:0.7.3-1) ...
# Setting up fonts-tlwg-loma-ttf (1:0.7.3-1) ...
# Setting up fonts-tlwg-typo-ttf (1:0.7.3-1) ...
# Setting up fonts-tlwg-kinnari-ttf (1:0.7.3-1) ...
# Setting up fonts-tlwg-umpush-ttf (1:0.7.3-1) ...
# Setting up fonts-tlwg-kinnari (1:0.7.3-1) ...
# Setting up fonts-tlwg-laksaman (1:0.7.3-1) ...
# Setting up fonts-tlwg-sawasdee-ttf (1:0.7.3-1) ...
# Setting up fonts-tlwg-typist-ttf (1:0.7.3-1) ...
# Setting up fonts-tlwg-typewriter-ttf (1:0.7.3-1) ...
# Setting up fonts-tlwg-garuda (1:0.7.3-1) ...
# Setting up fonts-tlwg-norasi-ttf (1:0.7.3-1) ...
# Setting up fonts-tlwg-waree-ttf (1:0.7.3-1) ...
# Setting up fonts-tlwg-loma (1:0.7.3-1) ...
# Setting up fonts-tlwg-purisa-ttf (1:0.7.3-1) ...
# Setting up fonts-tlwg-mono-ttf (1:0.7.3-1) ...
# Setting up fonts-tlwg-typewriter (1:0.7.3-1) ...
# Setting up fonts-tlwg-typo (1:0.7.3-1) ...
# Setting up fonts-tlwg-waree (1:0.7.3-1) ...
# Setting up fonts-tlwg-sawasdee (1:0.7.3-1) ...
# Setting up fonts-tlwg-typist (1:0.7.3-1) ...
# Setting up fonts-tlwg-umpush (1:0.7.3-1) ...
# Setting up fonts-tlwg-mono (1:0.7.3-1) ...
# Setting up fonts-tlwg-purisa (1:0.7.3-1) ...
# Setting up fonts-tlwg-norasi (1:0.7.3-1) ...
# Setting up fonts-thai-tlwg (1:0.7.3-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# ตั้งค่าระบบฟอนต์ภาษาไทยสำเร็จ!

# %% [markdown]
# ## ส่วนที่ 1 — เตรียม class และฟังก์ชัน

# %%
class Member:
    """ข้อมูลสมาชิกธนาคารออมทรัพย์"""
    def __init__(self, member_id, customer_name, citizen_id="-", phone_number="-"):
        self.member_id = member_id
        self.customer_name = customer_name
        self.citizen_id = citizen_id
        self.phone_number = phone_number

    def get_info(self):
        return f"ลูกค้า ID: {self.member_id} | ชื่อ: {self.customer_name} | เลขบัตรประชาชน: {self.citizen_id} | เบอร์โทร: {self.phone_number}"

# %%
class Account:
    """บัญชีเงินฝากธนาคารออมทรัพย์"""
    def __init__(self, account_number, balance, owner, interest_rate=0.015):
        self.account_number = account_number
        self.balance = float(balance)
        self.owner = owner #ชื่อเจ้าของบัญชี
        self.interest_rate = interest_rate  # ดอกเบี้ย 1.5% ต่อปี ( default )

    # Validation & Operations
    def deposit(self, amount):
        """ฝากเงิน: balance = balance + amount"""
        self.balance += amount
        return "ฝากเงินสำเร็จ"

    def withdraw(self, amount):
        """ถอนเงิน: ตรวจสอบ balance >= amount"""
        if self.balance < amount:
            return f"ยอดเงินไม่พอ (มีอยู่ {self.balance:,.2f} บาท)"
        self.balance -= amount
        return "ถอนเงินสำเร็จ"

    def transfer(self, target_account, amount):
        """โอนเงิน: ตัดบัญชีต้นทาง และบวกเข้าบัญชีปลายทาง"""
        if self.balance < amount:
            return f" ยอดเงินไม่พอโอน (มีอยู่ {self.balance:,.2f} บาท)"
        self.balance -= amount
        target_account.balance += amount
        return "โอนเงินสำเร็จ"

    def apply_interest(self):
        """คำนวณดอกเบี้ย: interest = balance * interest_rate แล้วบวกเข้ายอดคงเหลือ"""
        interest = self.balance * self.interest_rate
        self.balance += interest
        return interest

# %%
import random
from datetime import datetime, timedelta

# 1. ฟังก์ชันสุ่มคิว 35 - 50 รายการต่อวัน (ไม่ระบุชื่อ parameter เพื่อป้องกัน TypeError)
def generate_transaction_data(txn_id, min_items=35, max_items=50):
    base_date = datetime(2026, 8, 22)
    day_idx = 0
    total_items = 0

    while True:
        #random.seed(999 + day_idx)
        #items_today = random.randint(min_items, max_items)
        items_today = 40

        if txn_id <= total_items + items_today:
            queue_num = txn_id - total_items
            current_date = base_date + timedelta(days=day_idx)
            #random.seed(1)  # คืนค่า seed หลัก

            return {
                "วันที่": current_date.strftime("%d/%m/%Y"),
                "หมายเลขคิว": f"A-{queue_num:03d}",
                "queue_seq": queue_num - 1
            }

        total_items += items_today
        day_idx += 1

# 2. Class Transaction
class Transaction:
    def __init__(self, txn_id, account, transaction_type, amount, target_account=None):
        self.txn_id = txn_id

        # 📌 เรียกใช้โดยส่งค่า 35, 50 ตามลำดับตำแหน่งตรงๆ
        date_info = generate_transaction_data(txn_id, 35, 50)
        self.queue_number = date_info["หมายเลขคิว"]
        self.txn_date = date_info["วันที่"]

        # ⏰ คำนวณเวลาเดินหน้าตามลำดับคิวในวันนั้น
        base_start_time = datetime.strptime("08:30:00", "%H:%M:%S")
        queue_seq = date_info["queue_seq"]

        minutes_added = queue_seq * random.randint(8, 11) + random.randint(0, 2)
        seconds_added = random.randint(0, 59)

        actual_time = base_start_time + timedelta(minutes=minutes_added, seconds=seconds_added)
        self.time = actual_time.strftime("%H:%M:%S")

        self.account = account
        self.account_number = account.account_number
        self.customer_name = account.owner.customer_name
        self.transaction_type = transaction_type
        self.amount = amount
        self.target_account = target_account

    def to_dict(self):
        interest = getattr(self.account, "yearly_interest", 0.0)

        if isinstance(self.customer_name, (tuple, list)):
            fname, lname = self.customer_name[0], self.customer_name[1]
        else:
            parts = str(self.customer_name).split(" ", 1)
            fname = parts[0]
            lname = parts[1] if len(parts) > 1 else "-"

        return {
            "ID รายการ": self.txn_id,
            "หมายเลขคิว": self.queue_number,
            "วันที่ทำรายการ": self.txn_date,
            "เวลาทำรายการ": self.time,
            "เลขบัญชี": self.account_number,
            "ชื่อ": fname,
            "นามสกุล": lname,
            "ประเภทรายการ": self.transaction_type,
            "จำนวนเงิน": self.amount,
            "บัญชีปลายทาง": self.target_account if self.target_account else "-",
            "ยอดหลังทำรายการ": round(self.account.balance, 2),
            "ดอกเบี้ยสิ้นปี (1.5%)": round(interest, 2),
            "ยอดรวมดอกเบี้ยสุทธิ": round(self.account.balance + interest, 2)
        }

# %%
def generate_thai_name():
    """ฟังก์ชัน: สุ่มชื่อและนามสกุลลูกค้าแยกกัน"""
    name = fake.name()
    first_name, last_name = name.split(" ", 1)

    return f"{first_name} {last_name}"

def random_amount(min_val=100.0, max_val=2000.0):
    """ฟังก์ชัน: สุ่มยอดเงิน -> คืนค่าเป็น float """
    return round(random.uniform(min_val, max_val), 2)

def format_currency(amount, symbol="บาท"):
    """ฟังก์ชัน: จัดรูปแบบตัวเลขเป็นสตริงราคา -> คืนค่าเป็น string"""
    return f"{amount:,.2f} {symbol}"

# %% [markdown]
# ## ส่วนที่ 2 — ทดสอบฟังก์ชันทีละตัว ก่อนเอาไปประกอบเป็นกระบวนการ

# %%
# เรียก generate_thai_name() 3 ครั้ง -> ทุกครั้งได้ชื่อสุ่มไม่ซ้ำแบบ (แสดงว่าฟังก์ชันทำงานทุกครั้งที่เรียก)
for _ in range(3):
    print("ชื่อที่สุ่มได้:", generate_thai_name())
# Out:
# ชื่อที่สุ่มได้: จิม ถมังรักษสัตว์
# ชื่อที่สุ่มได้: ศดิศ นวลฉวี
# ชื่อที่สุ่มได้: จีรยุทธ ถาวรรัตน

# %%
print("\n# เรียก random_amount() 3 ครั้ง")
for _ in range(3):
    print("ยอดเงินสุ่มได้:", format_currency(random_amount()))
# Out:
# # เรียก random_amount() 3 ครั้ง
# ยอดเงินสุ่มได้: 355.29 บาท
# ยอดเงินสุ่มได้: 1,710.12 บาท
# ยอดเงินสุ่มได้: 1,551.17 บาท

# %% [markdown]
# ## ส่วนที่ 3 — ฟังก์ชันอธิบายขั้นตอนคำนวณราคา (ให้เห็นว่าฟังก์ชันเรียกฟังก์ชัน/method อื่นต่อได้)

# %%
def explain_transaction_calculation(transaction):
    """ฟังก์ชันคำนวณเงิน ฝาก/ถอน/โอน และเรียกใช้ Method ของ Account"""

    account = transaction.account
    amount = float(transaction.amount)
    txn_type = transaction.transaction_type

    print(f"หมายเลขคิว = '{transaction.queue_number}'")
    print(f"หมายเลขบัญชี = '{account.account_number}'")
    print(f"ชื่อลูกค้า = '{transaction.customer_name}'")
    print(f"ประเภทรายการ = '{txn_type}'")
    print(f"ยอดเงินก่อนทำรายการ = {format_currency(account.balance)}")

    # 📌 เรียกใช้ Method ภายใน Class Account
    if txn_type == "ฝากเงิน":
        status_msg = account.deposit(amount)

    elif txn_type == "ถอนเงิน":
        status_msg = account.withdraw(amount)
        # ❌ ถ้าเงินไม่พอ ให้หยุดประมวลผลทันที
        if "ยอดเงินไม่พอ" in status_msg:
            print(f"จำนวนเงินทำรายการ = {format_currency(amount)}")
            print(f"สถานะรายการ = '{status_msg}'")
            return False

    elif txn_type == "โอนเงิน":
        if transaction.target_account:
            print(f"บัญชีปลายทาง = '{transaction.target_account}'")

        dummy_member = Member(0, "บัญชีปลายทาง")
        dummy_target = Account("987-6-00000-0", balance=0.0, owner=dummy_member)
        status_msg = account.transfer(dummy_target, amount)
        # ❌ ถ้าเงินไม่พอโอน ให้หยุดประมวลผลทันที
        if "ยอดเงินไม่พอ" in status_msg:
            print(f"จำนวนเงินทำรายการ = {format_currency(amount)}")
            print(f"สถานะรายการ = '{status_msg}'")
            return False

    # คำนวณดอกเบี้ย (จะทำเฉพาะรายการที่สำเร็จเท่านั้น)
    interest_val = account.apply_interest()

    print(f"จำนวนเงินทำรายการ = {format_currency(amount)}")
    print(f"ยอดเงินคงเหลือหลังทำรายการ = {format_currency(account.balance)}")
    print(f"สถานะรายการ = '{status_msg}'")
    print(f"ดอกเบี้ยที่ได้รับเมื่อสิ้นปี (1.5%) = {format_currency(interest_val)}")

    return True

# %%
import random

# 1. กำหนด seed และเตรียมตัวแปร
random.seed(1)
transactions = []

# 2. Loop สุ่มข้อมูล 300 รายการ
for i in range(1, 301):
    name = generate_thai_name()
    amount = random_amount()
    service = random.choice(["ฝากเงิน", "ถอนเงิน", "โอนเงิน"])

    member = Member(member_id=1 + i, customer_name=name)

    initial_balance = round(random.uniform(100, 5000), 2)

    # 🎲 สุ่มเลขบัญชีลูกค้า
    acc_p1 = random.randint(100, 999)
    acc_p2 = random.randint(1, 9)
    acc_p3 = random.randint(10000, 99999)
    random_account_no = f"{acc_p1}-{acc_p2}-{acc_p3:05d}-0"

    account = Account(account_number=random_account_no, balance=initial_balance, owner=member)
    target_acc = f"987-6-{random.randint(10000, 99999)}-0" if service == "โอนเงิน" else None
    # 📌 คำนวณยอดเงินผ่าน Method ของ Account โดยตรง
    if service == "ฝากเงิน":
        account.deposit(amount)
    elif service == "ถอนเงิน":
        account.withdraw(amount)
    elif service == "โอนเงิน":
        dummy_mem = Member(0, "ปลายทาง")
        dummy_acc = Account("987-6-00000-0", balance=0.0, owner=dummy_mem)
        account.transfer(dummy_acc, amount)

    # ประมวลผลดอกเบี้ย
    account.apply_interest()

    transaction = Transaction(
        txn_id=i,
        account=account,
        transaction_type=service,
        amount=amount,
        target_account=target_acc
    )

    transactions.append(transaction)

# 3. แสดงตัวอย่างรายการแรก (คิว A-001)
print("\n--- [ตัวอย่างการแสดงผลรายการแรก (คิว A-001)] ---")
explain_transaction_calculation(transactions[0])
# Out:
# --- [ตัวอย่างการแสดงผลรายการแรก (คิว A-001)] ---
# หมายเลขคิว = 'A-001'
# หมายเลขบัญชี = '607-8-71898-0'
# ชื่อลูกค้า = 'จณิตตา ทรัพย์ธำรงค์'
# ประเภทรายการ = 'ฝากเงิน'
# ยอดเงินก่อนทำรายการ = 1,730.71 บาท
# จำนวนเงินทำรายการ = 355.29 บาท
# ยอดเงินคงเหลือหลังทำรายการ = 2,117.29 บาท
# สถานะรายการ = 'ฝากเงินสำเร็จ'
# ดอกเบี้ยที่ได้รับเมื่อสิ้นปี (1.5%) = 31.29 บาท
# True

# %% [markdown]
# ## ส่วนที่ 4 — จำลอง "ลูกค้า 1 คนเดินเข้าร้าน" แบบ step-by-step

# %%
import random
import time

def simulate_customer_visit(txn_id, customer_name, pause=0.5):
    """จำลองขั้นตอนลูกค้า 1 คนเดินเข้าธนาคาร"""
    print("=" * 60)
    queue_no = f"A-{txn_id:03d}"
    print(f"🎫 [ผู้ออกบัตรคิว] คุณ '{customer_name}' กดรับบัตรคิว ได้หมายเลข: {queue_no}")

    # 1. สร้าง Member
    member = Member(member_id=100 + txn_id, customer_name=customer_name)

    # 2. 🎲 สุ่มยอดเงินตั้งต้น (1,000 - 5,000 บาท)
    initial_balance = round(random.uniform(100, 5000), 2)

    # 3. 🎲 สุ่มเลขบัญชีลูกค้า (รูปแบบ 123-4-56789-0)
    acc_p1 = random.randint(100, 999)
    acc_p2 = random.randint(1, 9)
    acc_p3 = random.randint(10000, 99999)
    random_account_no = f"{acc_p1}-{acc_p2}-{acc_p3:05d}-0"

    # 4. สร้าง Account
    account = Account(account_number=random_account_no, balance=initial_balance, owner=member)

    # 5. สุ่มประเภทรายการ และจำนวนเงิน
    service = random.choice(["ฝากเงิน", "ถอนเงิน", "โอนเงิน"])
    amount = random_amount()
    target_acc = f"987-6-{random.randint(10000, 99999)}-0" if service == "โอนเงิน" else None

    # 6. ประมวลผลธุรกรรม
    print(f"🔔 [เชิญหมายเลข {queue_no}] เข้าเคาน์เตอร์บริการ -> แจ้งทำรายการ: '{service}'")
    time.sleep(pause)
    print("⚙️ เจ้าหน้าที่บันทึกข้อมูลเข้าระบบ (สถานะ: กำลังดำเนินการ)")
    time.sleep(pause)

    if service == "ฝากเงิน":
        account.deposit(amount)
    elif service == "ถอนเงิน":
        account.withdraw(amount)
    elif service == "โอนเงิน":
        dummy_mem = Member(0, "ปลายทาง")
        dummy_acc = Account("987-6-00000-0", balance=0.0, owner=dummy_mem)
        account.transfer(dummy_acc, amount)

    # คิดดอกเบี้ย
    account.apply_interest()

    # 7. สร้าง Transaction
    txn = Transaction(
        txn_id=txn_id,
        account=account,
        transaction_type=service,
        amount=amount,
        target_account=target_acc
    )

    # แสดงรายละเอียดคำนวณ
    print("💻 เจ้าหน้าที่ตรวจสอบยอดเงินและประเภทรายการ:")
    explain_transaction_calculation(txn)

    # 📌 เพิ่มส่วนพิมพ์สลิปตรงนี้ครับ
    print("✅ ทำรายการสำเร็จ!")

    # ปรับรูปแบบชื่อกรณีที่เป็น Tuple/List ให้แสดงเป็นข้อความเรียบง่าย
    display_name = " ".join(customer_name) if isinstance(customer_name, (tuple, list)) else customer_name
    print(f"🧾 สลิปบันทึกรายการ #{txn.txn_id}: คิว {txn.queue_number} | วันที่ {txn.txn_date} | เวลา {txn.time} | คุณ {display_name} | {service} | ยอด {format_currency(amount)} | ยอดคงเหลือสุทธิ {format_currency(account.balance)}")
    return txn

# %%
# --- [ทดสอบเรียกใช้งานจริงกับลูกค้า 1 คน] ---
transaction_a = simulate_customer_visit(txn_id=1, customer_name="สมหญิง สายทอง", pause=0.5)
# Out:
# ============================================================
# 🎫 [ผู้ออกบัตรคิว] คุณ 'สมหญิง สายทอง' กดรับบัตรคิว ได้หมายเลข: A-001
# 🔔 [เชิญหมายเลข A-001] เข้าเคาน์เตอร์บริการ -> แจ้งทำรายการ: 'โอนเงิน'
# ⚙️ เจ้าหน้าที่บันทึกข้อมูลเข้าระบบ (สถานะ: กำลังดำเนินการ)
# 💻 เจ้าหน้าที่ตรวจสอบยอดเงินและประเภทรายการ:
# หมายเลขคิว = 'A-001'
# หมายเลขบัญชี = '524-6-86672-0'
# ชื่อลูกค้า = 'สมหญิง สายทอง'
# ประเภทรายการ = 'โอนเงิน'
# ยอดเงินก่อนทำรายการ = 3,194.43 บาท
# บัญชีปลายทาง = '987-6-69568-0'
# จำนวนเงินทำรายการ = 189.87 บาท
# ยอดเงินคงเหลือหลังทำรายการ = 3,049.63 บาท
# สถานะรายการ = 'โอนเงินสำเร็จ'
# ดอกเบี้ยที่ได้รับเมื่อสิ้นปี (1.5%) = 45.07 บาท
# ✅ ทำรายการสำเร็จ!
# 🧾 สลิปบันทึกรายการ #1: คิว A-001 | วันที่ 22/08/2026 | เวลา 08:32:58 | คุณ สมหญิง สายทอง | โอนเงิน | ยอด 189.87 บาท | ยอดคงเหลือสุทธิ 3,049.63 บาท

# %% [markdown]
# ##  ส่วนที่ 5 — จำลองลูกค้าหลายคนเดินเข้าธนาคารต่อเนื่องกัน

# %%
walk_in_customers = []

for i in range(2, 11):
    customer_name = fake.name()

    walk_in_customers.append(
        Member(
            member_id=i,
            customer_name=customer_name
        )
    )
completed_transactions = []  # เก็บผลลัพธ์ของทุกรายการในรอบนี้

for i, cust in enumerate(walk_in_customers, start=2):
    # ส่งชื่อลูกค้าเข้าฟังก์ชัน simulate_customer_visit
    txn = simulate_customer_visit(txn_id=i, customer_name=cust.customer_name, pause=0.3)
    completed_transactions.append(txn)

print("=" * 60)
print(f"🏁 จบการสาธิต — วันนี้มีลูกค้าเข้าทำรายการทั้งหมด {len(completed_transactions) + 1} คน (รวมคิว #1 ก่อนหน้า)")
# Out:
# ============================================================
# 🎫 [ผู้ออกบัตรคิว] คุณ 'วสิตา ธรรมทินนา' กดรับบัตรคิว ได้หมายเลข: A-002
# 🔔 [เชิญหมายเลข A-002] เข้าเคาน์เตอร์บริการ -> แจ้งทำรายการ: 'ฝากเงิน'
# ⚙️ เจ้าหน้าที่บันทึกข้อมูลเข้าระบบ (สถานะ: กำลังดำเนินการ)
# 💻 เจ้าหน้าที่ตรวจสอบยอดเงินและประเภทรายการ:
# หมายเลขคิว = 'A-002'
# หมายเลขบัญชี = '698-1-55790-0'
# ชื่อลูกค้า = 'วสิตา ธรรมทินนา'
# ประเภทรายการ = 'ฝากเงิน'
# ยอดเงินก่อนทำรายการ = 4,427.18 บาท
# จำนวนเงินทำรายการ = 1,698.26 บาท
# ยอดเงินคงเหลือหลังทำรายการ = 6,217.32 บาท
# สถานะรายการ = 'ฝากเงินสำเร็จ'
# ดอกเบี้ยที่ได้รับเมื่อสิ้นปี (1.5%) = 91.88 บาท
# ✅ ทำรายการสำเร็จ!
# 🧾 สลิปบันทึกรายการ #2: คิว A-002 | วันที่ 22/08/2026 | เวลา 08:41:40 | คุณ วสิตา ธรรมทินนา | ฝากเงิน | ยอด 1,698.26 บาท | ยอดคงเหลือสุทธิ 6,217.32 บาท
# ============================================================
# 🎫 [ผู้ออกบัตรคิว] คุณ 'ธีริสรา ธรรมฤดี' กดรับบัตรคิว ได้หมายเลข: A-003
# 🔔 [เชิญหมายเลข A-003] เข้าเคาน์เตอร์บริการ -> แจ้งทำรายการ: 'ฝากเงิน'
# ⚙️ เจ้าหน้าที่บันทึกข้อมูลเข้าระบบ (สถานะ: กำลังดำเนินการ)
# 💻 เจ้าหน้าที่ตรวจสอบยอดเงินและประเภทรายการ:
# หมายเลขคิว = 'A-003'
# หมายเลขบัญชี = '252-1-57896-0'
# ชื่อลูกค้า = 'ธีริสรา ธรรมฤดี'
# ประเภทรายการ = 'ฝากเงิน'
# ยอดเงินก่อนทำรายการ = 1,112.58 บาท
# จำนวนเงินทำรายการ = 385.87 บาท
# ยอดเงินคงเหลือหลังทำรายการ = 1,520.93 บาท
# สถานะรายการ = 'ฝากเงินสำเร็จ'
# ดอกเบี้ยที่ได้รับเมื่อสิ้นปี (1.5%) = 22.48 บาท
# ✅ ทำรายการสำเร็จ!
# 🧾 สลิปบันทึกรายการ #3: คิว A-003 | วันที่ 22/08/2026 | เวลา 08:47:40 | คุณ ธีริสรา ธรรมฤดี | ฝากเงิน | ยอด 385.87 บาท | ยอดคงเหลือสุทธิ 1,520.93 บาท
# ============================================================
# 🎫 [ผู้ออกบัตรคิว] คุณ 'ซูรัยดา นามขำ' กดรับบัตรคิว ได้หมายเลข: A-004
# 🔔 [เชิญหมายเลข A-004] เข้าเคาน์เตอร์บริการ -> แจ้งทำรายการ: 'ถอนเงิน'
# ⚙️ เจ้าหน้าที่บันทึกข้อมูลเข้าระบบ (สถานะ: กำลังดำเนินการ)
# 💻 เจ้าหน้าที่ตรวจสอบยอดเงินและประเภทรายการ:
# หมายเลขคิว = 'A-004'
# หมายเลขบัญชี = '168-7-22039-0'
# ชื่อลูกค้า = 'ซูรัยดา นามขำ'
# ประเภทรายการ = 'ถอนเงิน'
# ยอดเงินก่อนทำรายการ = 234.62 บาท
# จำนวนเงินทำรายการ = 1,133.79 บาท
# สถานะรายการ = 'ยอดเงินไม่พอ (มีอยู่ 234.62 บาท)'
# ✅ ทำรายการสำเร็จ!
# 🧾 สลิปบันทึกรายการ #4: คิว A-004 | วันที่ 22/08/2026 | เวลา 08:54:34 | คุณ ซูรัยดา นามขำ | ถอนเงิน | ยอด 1,133.79 บาท | ยอดคงเหลือสุทธิ 234.62 บาท
# ============================================================
# 🎫 [ผู้ออกบัตรคิว] คุณ 'อชิตะวีร์ บุญญาไลย์' กดรับบัตรคิว ได้หมายเลข: A-005
# 🔔 [เชิญหมายเลข A-005] เข้าเคาน์เตอร์บริการ -> แจ้งทำรายการ: 'โอนเงิน'
# ⚙️ เจ้าหน้าที่บันทึกข้อมูลเข้าระบบ (สถานะ: กำลังดำเนินการ)
# 💻 เจ้าหน้าที่ตรวจสอบยอดเงินและประเภทรายการ:
# หมายเลขคิว = 'A-005'
# หมายเลขบัญชี = '823-7-94301-0'
# ชื่อลูกค้า = 'อชิตะวีร์ บุญญาไลย์'
# ประเภทรายการ = 'โอนเงิน'
# ยอดเงินก่อนทำรายการ = 3,166.91 บาท
# บัญชีปลายทาง = '987-6-63755-0'
# จำนวนเงินทำรายการ = 1,135.31 บาท
# ยอดเงินคงเหลือหลังทำรายการ = 2,062.08 บาท
# สถานะรายการ = 'โอนเงินสำเร็จ'
# ดอกเบี้ยที่ได้รับเมื่อสิ้นปี (1.5%) = 30.47 บาท
# ✅ ทำรายการสำเร็จ!
# 🧾 สลิปบันทึกรายการ #5: คิว A-005 | วันที่ 22/08/2026 | เวลา 09:08:24 | คุณ อชิตะวีร์ บุญญาไลย์ | โอนเงิน | ยอด 1,135.31 บาท | ยอดคงเหลือสุทธิ 2,062.08 บาท
# ============================================================
# 🎫 [ผู้ออกบัตรคิว] คุณ 'ประภัทร์สรณ์ ถนอมกุลบุตร' กดรับบัตรคิว ได้หมายเลข: A-006
# 🔔 [เชิญหมายเลข A-006] เข้าเคาน์เตอร์บริการ -> แจ้งทำรายการ: 'ฝากเงิน'
# ⚙️ เจ้าหน้าที่บันทึกข้อมูลเข้าระบบ (สถานะ: กำลังดำเนินการ)
# 💻 เจ้าหน้าที่ตรวจสอบยอดเงินและประเภทรายการ:
# หมายเลขคิว = 'A-006'
# หมายเลขบัญชี = '851-6-67391-0'
# ชื่อลูกค้า = 'ประภัทร์สรณ์ ถนอมกุลบุตร'
# ประเภทรายการ = 'ฝากเงิน'
# ยอดเงินก่อนทำรายการ = 2,708.00 บาท
# จำนวนเงินทำรายการ = 227.78 บาท
# ยอดเงินคงเหลือหลังทำรายการ = 2,979.82 บาท
# สถานะรายการ = 'ฝากเงินสำเร็จ'
# ดอกเบี้ยที่ได้รับเมื่อสิ้นปี (1.5%) = 44.04 บาท
# ✅ ทำรายการสำเร็จ!
# 🧾 สลิปบันทึกรายการ #6: คิว A-006 | วันที่ 22/08/2026 | เวลา 09:20:06 | คุณ ประภัทร์สรณ์ ถนอมกุลบุตร | ฝากเงิน | ยอด 227.78 บาท | ยอดคงเหลือสุทธิ 2,979.82 บาท
# ============================================================
# 🎫 [ผู้ออกบัตรคิว] คุณ 'เมษา ภูภักดี' กดรับบัตรคิว ได้หมายเลข: A-007
# 🔔 [เชิญหมายเลข A-007] เข้าเคาน์เตอร์บริการ -> แจ้งทำรายการ: 'โอนเงิน'
# ⚙️ เจ้าหน้าที่บันทึกข้อมูลเข้าระบบ (สถานะ: กำลังดำเนินการ)
# 💻 เจ้าหน้าที่ตรวจสอบยอดเงินและประเภทรายการ:
# หมายเลขคิว = 'A-007'
# หมายเลขบัญชี = '300-2-95747-0'
# ชื่อลูกค้า = 'เมษา ภูภักดี'
# ประเภทรายการ = 'โอนเงิน'
# ยอดเงินก่อนทำรายการ = 1,596.41 บาท
# บัญชีปลายทาง = '987-6-77157-0'
# จำนวนเงินทำรายการ = 266.26 บาท
# ยอดเงินคงเหลือหลังทำรายการ = 1,350.10 บาท
# สถานะรายการ = 'โอนเงินสำเร็จ'
# ดอกเบี้ยที่ได้รับเมื่อสิ้นปี (1.5%) = 19.95 บาท
# ✅ ทำรายการสำเร็จ!
# 🧾 สลิปบันทึกรายการ #7: คิว A-007 | วันที่ 22/08/2026 | เวลา 09:36:05 | คุณ เมษา ภูภักดี | โอนเงิน | ยอด 266.26 บาท | ยอดคงเหลือสุทธิ 1,350.10 บาท
# ============================================================
# 🎫 [ผู้ออกบัตรคิว] คุณ 'ยูซุฟ ตัณสถิตย์' กดรับบัตรคิว ได้หมายเลข: A-008
# 🔔 [เชิญหมายเลข A-008] เข้าเคาน์เตอร์บริการ -> แจ้งทำรายการ: 'ถอนเงิน'
# ⚙️ เจ้าหน้าที่บันทึกข้อมูลเข้าระบบ (สถานะ: กำลังดำเนินการ)
# 💻 เจ้าหน้าที่ตรวจสอบยอดเงินและประเภทรายการ:
# หมายเลขคิว = 'A-008'
# หมายเลขบัญชี = '726-1-85166-0'
# ชื่อลูกค้า = 'ยูซุฟ ตัณสถิตย์'
# ประเภทรายการ = 'ถอนเงิน'
# ยอดเงินก่อนทำรายการ = 447.83 บาท
# จำนวนเงินทำรายการ = 1,164.92 บาท
# สถานะรายการ = 'ยอดเงินไม่พอ (มีอยู่ 447.83 บาท)'
# ✅ ทำรายการสำเร็จ!
# 🧾 สลิปบันทึกรายการ #8: คิว A-008 | วันที่ 22/08/2026 | เวลา 09:49:02 | คุณ ยูซุฟ ตัณสถิตย์ | ถอนเงิน | ยอด 1,164.92 บาท | ยอดคงเหลือสุทธิ 447.83 บาท
# ============================================================
# 🎫 [ผู้ออกบัตรคิว] คุณ 'พิไลพร ทองสีไพล' กดรับบัตรคิว ได้หมายเลข: A-009
# 🔔 [เชิญหมายเลข A-009] เข้าเคาน์เตอร์บริการ -> แจ้งทำรายการ: 'ถอนเงิน'
# ⚙️ เจ้าหน้าที่บันทึกข้อมูลเข้าระบบ (สถานะ: กำลังดำเนินการ)
# 💻 เจ้าหน้าที่ตรวจสอบยอดเงินและประเภทรายการ:
# หมายเลขคิว = 'A-009'
# หมายเลขบัญชี = '129-5-91320-0'
# ชื่อลูกค้า = 'พิไลพร ทองสีไพล'
# ประเภทรายการ = 'ถอนเงิน'
# ยอดเงินก่อนทำรายการ = 2,488.63 บาท
# จำนวนเงินทำรายการ = 931.98 บาท
# ยอดเงินคงเหลือหลังทำรายการ = 1,580.00 บาท
# สถานะรายการ = 'ถอนเงินสำเร็จ'
# ดอกเบี้ยที่ได้รับเมื่อสิ้นปี (1.5%) = 23.35 บาท
# ✅ ทำรายการสำเร็จ!
# 🧾 สลิปบันทึกรายการ #9: คิว A-009 | วันที่ 22/08/2026 | เวลา 09:51:49 | คุณ พิไลพร ทองสีไพล | ถอนเงิน | ยอด 931.98 บาท | ยอดคงเหลือสุทธิ 1,580.00 บาท
# ============================================================
# 🎫 [ผู้ออกบัตรคิว] คุณ 'คมคาย ฉิมพาลี' กดรับบัตรคิว ได้หมายเลข: A-010
# 🔔 [เชิญหมายเลข A-010] เข้าเคาน์เตอร์บริการ -> แจ้งทำรายการ: 'ฝากเงิน'
# ⚙️ เจ้าหน้าที่บันทึกข้อมูลเข้าระบบ (สถานะ: กำลังดำเนินการ)
# 💻 เจ้าหน้าที่ตรวจสอบยอดเงินและประเภทรายการ:
# หมายเลขคิว = 'A-010'
# หมายเลขบัญชี = '589-8-79994-0'
# ชื่อลูกค้า = 'คมคาย ฉิมพาลี'
# ประเภทรายการ = 'ฝากเงิน'
# ยอดเงินก่อนทำรายการ = 5,551.05 บาท
# จำนวนเงินทำรายการ = 610.88 บาท
# ยอดเงินคงเหลือหลังทำรายการ = 6,254.35 บาท
# สถานะรายการ = 'ฝากเงินสำเร็จ'
# ดอกเบี้ยที่ได้รับเมื่อสิ้นปี (1.5%) = 92.43 บาท
# ✅ ทำรายการสำเร็จ!
# 🧾 สลิปบันทึกรายการ #10: คิว A-010 | วันที่ 22/08/2026 | เวลา 09:53:45 | คุณ คมคาย ฉิมพาลี | ฝากเงิน | ยอด 610.88 บาท | ยอดคงเหลือสุทธิ 6,254.35 บาท
# ============================================================
# 🏁 จบการสาธิต — วันนี้มีลูกค้าเข้าทำรายการทั้งหมด 10 คน (รวมคิว #1 ก่อนหน้า)

# %% [markdown]
# ## ส่วนที่ 6 — สรุปผลจากการ demo (ยืนยันว่าฟังก์ชันคืนค่าถูกต้องและใช้ต่อได้จริง

# %%
import pandas as pd

# ดึงข้อมูลจาก transactions (300 รายการ) มาทำตาราง
summary_rows = [
    {
        "txn_id": t.txn_id,
        "queue_number": f"A-{t.txn_id:03d}",
        "account_number": t.account.account_number,
        "date": t.txn_date,
        "customer_name": " ".join(t.customer_name) if isinstance(t.customer_name, (tuple, list)) else t.customer_name,
        "transaction_type": t.transaction_type,
        "amount": t.amount,
        "balance_after": round(t.account.balance, 2),
        "target_account": t.target_account if t.target_account else "-"
    }
    for t in transactions  # 📌 ใช้ transactions แทน all_demo_transactions
]

summary_df = pd.DataFrame(summary_rows)
summary_df
# Out:
#      txn_id queue_number account_number        date          customer_name  \
# 0         1        A-001  607-8-71898-0  22/08/2026    จณิตตา ทรัพย์ธำรงค์
# 1         2        A-002  880-1-68377-0  22/08/2026        วันฉัตร ไตรบรรพ
# 2         3        A-003  131-1-13335-0  22/08/2026     ผกาทิพย์ เช้าวันดี
# 3         4        A-004  640-4-67394-0  22/08/2026          เขียว ศรีอุ่น
# 4         5        A-005  570-5-12816-0  22/08/2026  ฉัตรปรียา ธูปะวิโรจน์
# ..      ...          ...            ...         ...                    ...
# 295     296        A-296  932-2-62465-0  29/08/2026     ทองรัตน์ ดำริห์ชอบ
# 296     297        A-297  767-8-97432-0  29/08/2026  พุทธิพงษ์ ดุริยพันธุ์
# 297     298        A-298  476-9-36993-0  29/08/2026      ชัชนันท์ ธรรมนิยม
# 298     299        A-299  503-8-90825-0  29/08/2026   พิมพ์พิชญา เธียรายัน
# 299     300        A-300  540-5-64453-0  29/08/2026      สุทธิพจน์ เดชคุ้ม
#
#     transaction_type   amount  balance_after target_account
# 0            ฝากเงิน   355.29        2117.29              -
# 1            ถอนเงิน  1026.93        1211.53              -
# 2            ฝากเงิน   534.65        5127.41              -
# 3            ถอนเงิน   511.54        3192.32              -
# 4            โอนเงิน   756.83         421.43  987-6-64549-0
# ..               ...      ...            ...            ...
# 295          ฝากเงิน  1086.05        5169.14              -
# 296          โอนเงิน  1465.40        1213.91  987-6-46782-0
# 297          ถอนเงิน  1331.30         796.26              -
# 298          ฝากเงิน   552.20        1860.77              -
# 299          โอนเงิน   202.96         139.23  987-6-27405-0
#
# [300 rows x 9 columns]

# %%
# Save to csv
summary_df.to_csv("สหกรณ์ออมทรัพย์.csv")

# %% [markdown]
# ## ส่วนที่ 7 — สรุปผล 300 คน

# %%
# คำนวณยอดหมุนเวียนรวมทำรายการในรอบ demo
total_volume = sum(t.amount for t in transactions)
print(f"\n📊 ยอดธุรกรรมทำรายการรวมจากลูกค้าที่เดินเข้าธนาคารในรอบ demo นี้: {format_currency(total_volume)}")
# Out:
# 📊 ยอดธุรกรรมทำรายการรวมจากลูกค้าที่เดินเข้าธนาคารในรอบ demo นี้: 312,954.47 บาท
